# %%
import pandas as pd
df=pd.read_csv("students.csv")
df
# Out:
#      StudentID                 Name  Age                          Email  \
# 0         3336         David Palmer   19             sean43@hotmail.com
# 1         8774         Andrew Roach   23             vbecker@harvey.com
# 2         1396    Jonathan Gonzalez   22           hollydavis@gmail.com
# 3         6716       Kenneth Morrow   24  ganderson@wheeler-atkins.info
# 4         8830     Kaitlyn Martinez   18           hayesdiane@gmail.com
# ..         ...                  ...  ...                            ...
# 195       3274  Catherine Velasquez   22              fsutton@gmail.com
# 196       3609         Joyce Thomas   19          zanderson@barrera.net
# 197       9179       Theresa Hughes   21             mstanley@yahoo.com
# 198       4463        Steven Golden   19             nvasquez@yahoo.com
# 199       6178     Miss April Smith   20       logansanchez@manning.com
#
#            Department   GPA  GraduationYear
# 0         Mathematics  3.16            2026
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      StudentID                 Name  Age                          Email  \
# 0         3336         David Palmer   19             sean43@hotmail.com
# 1         8774         Andrew Roach   23             vbecker@harvey.com
# 2         1396    Jonathan Gonzalez   22           hollydavis@gmail.com
# 3         6716       Kenneth Morrow   24  ganderson@wheeler-atkins.info
# 4         8830     Kaitlyn Martinez   18           hayesdiane@gmail.com
# ..         ...                  ...  ...                            ...
# 195       3274  Catherine Velasquez   22              fsutton@gmail.com
# 196       3609         Joyce Thomas   19          zanderson@barrera.net
# 197       9179       Theresa Hughes   21             mstanley@yahoo.com
# 198       4463        Steven Golden   19             nvasquez@yahoo.com
# 199       6178     Miss April Smith   20       logansanchez@manning.com
#
#            Department   GPA  GraduationYear
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   StudentID       200 non-null    int64
#  1   Name            200 non-null    object
#  2   Age             200 non-null    int64
#  3   Email           200 non-null    object
#  4   Department      200 non-null    object
#  5   GPA             200 non-null    float64
#  6   GraduationYear  200 non-null    int64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 8.7+ KB

# %%
df.isnull()
# Out:
#      StudentID   Name    Age  Email  Department    GPA  GraduationYear
# 0        False  False  False  False       False  False           False
# 1        False  False  False  False       False  False           False
# 2        False  False  False  False       False  False           False
# 3        False  False  False  False       False  False           False
# 4        False  False  False  False       False  False           False
# ..         ...    ...    ...    ...         ...    ...             ...
# 195      False  False  False  False       False  False           False
# 196      False  False  False  False       False  False           False
# 197      False  False  False  False       False  False           False
# 198      False  False  False  False       False  False           False
# 199      False  False  False  False       False  False           False
#
# [200 rows x 7 columns]

# %%
df.tail(5)
# Out:
#      StudentID                 Name  Age                     Email  \
# 195       3274  Catherine Velasquez   22         fsutton@gmail.com
# 196       3609         Joyce Thomas   19     zanderson@barrera.net
# 197       9179       Theresa Hughes   21        mstanley@yahoo.com
# 198       4463        Steven Golden   19        nvasquez@yahoo.com
# 199       6178     Miss April Smith   20  logansanchez@manning.com
#
#            Department   GPA  GraduationYear
# 195           Physics  2.71            2025
# 196         Chemistry  2.22            2030
# 197       Mathematics  3.23            2025
# 198  Computer Science  3.90            2025
# 199       Mathematics  3.15            2028

# %%
df.head(5)
# Out:
#    StudentID               Name  Age                          Email  \
# 0       3336       David Palmer   19             sean43@hotmail.com
# 1       8774       Andrew Roach   23             vbecker@harvey.com
# 2       1396  Jonathan Gonzalez   22           hollydavis@gmail.com
# 3       6716     Kenneth Morrow   24  ganderson@wheeler-atkins.info
# 4       8830   Kaitlyn Martinez   18           hayesdiane@gmail.com
#
#     Department   GPA  GraduationYear
# 0  Mathematics  3.16            2026
# 1    Chemistry  3.75            2027
# 2      Physics  2.95            2027
# 3      Physics  3.55            2029
# 4    Chemistry  2.29            2025

# %%
df.describe()
# Out:
#          StudentID         Age        GPA  GraduationYear
# count   200.000000  200.000000  200.00000      200.000000
# mean   5726.460000   21.580000    3.02785     2027.180000
# std    2507.407622    2.267002    0.59112        2.011924
# min    1066.000000   18.000000    2.00000     2024.000000
# 25%    3693.000000   20.000000    2.52500     2025.000000
# 50%    5641.000000   22.000000    3.08000     2027.000000
# 75%    8025.750000   24.000000    3.51000     2029.000000
# max    9985.000000   25.000000    3.99000     2030.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   StudentID       200 non-null    int64
#  1   Name            200 non-null    object
#  2   Age             200 non-null    int64
#  3   Email           200 non-null    object
#  4   Department      200 non-null    object
#  5   GPA             200 non-null    float64
#  6   GraduationYear  200 non-null    int64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 8.7+ KB

# %%
df
# Out:
#      StudentID                 Name  Age                          Email  \
# 0         3336         David Palmer   19             sean43@hotmail.com
# 1         8774         Andrew Roach   23             vbecker@harvey.com
# 2         1396    Jonathan Gonzalez   22           hollydavis@gmail.com
# 3         6716       Kenneth Morrow   24  ganderson@wheeler-atkins.info
# 4         8830     Kaitlyn Martinez   18           hayesdiane@gmail.com
# ..         ...                  ...  ...                            ...
# 195       3274  Catherine Velasquez   22              fsutton@gmail.com
# 196       3609         Joyce Thomas   19          zanderson@barrera.net
# 197       9179       Theresa Hughes   21             mstanley@yahoo.com
# 198       4463        Steven Golden   19             nvasquez@yahoo.com
# 199       6178     Miss April Smith   20       logansanchez@manning.com
#
#            Department   GPA  GraduationYear
# 0         Mathematics  3.16            2026
# ...

# %%
df.math_score.fillna(67)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-77d67311709f> in ?()
# ----> 1 df.math_score.fillna(67)
#
# /lib/python3.13/site-packages/pandas/core/generic.py in ?(self, name)
#    6314             and name not in self._accessors
#    6315             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6316         ):
#    6317             return self[name]
# -> 6318         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'math_score'

# %%
df.columns.values
# Out:
# array(['StudentID', 'Name', 'Age', 'Email', 'Department', 'GPA',
#        'GraduationYear'], dtype=object)

# %%
df.iloc[20]
# Out:
# StudentID                            3052
# Name                        Suzanne Lopez
# Age                                    18
# Email             thomasbennett@gmail.com
# Department               Computer Science
# GPA                                  2.33
# GraduationYear                       2025
# Name: 20, dtype: object

# %%
df.iloc[:,2:5]
# Out:
#      Age                          Email        Department
# 0     19             sean43@hotmail.com       Mathematics
# 1     23             vbecker@harvey.com         Chemistry
# 2     22           hollydavis@gmail.com           Physics
# 3     24  ganderson@wheeler-atkins.info           Physics
# 4     18           hayesdiane@gmail.com         Chemistry
# ..   ...                            ...               ...
# 195   22              fsutton@gmail.com           Physics
# 196   19          zanderson@barrera.net         Chemistry
# 197   21             mstanley@yahoo.com       Mathematics
# 198   19             nvasquez@yahoo.com  Computer Science
# 199   20       logansanchez@manning.com       Mathematics
#
# [200 rows x 3 columns]

# %%
df.math_score.fillna(67, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-8dd9c0eeb38b> in ?()
# ----> 1 df.math_score.fillna(67, inplace=True)
#
# /lib/python3.13/site-packages/pandas/core/generic.py in ?(self, name)
#    6314             and name not in self._accessors
#    6315             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6316         ):
#    6317             return self[name]
# -> 6318         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'math_score'

# %%
df
# Out:
#      StudentID                 Name  Age                          Email  \
# 0         3336         David Palmer   19             sean43@hotmail.com
# 1         8774         Andrew Roach   23             vbecker@harvey.com
# 2         1396    Jonathan Gonzalez   22           hollydavis@gmail.com
# 3         6716       Kenneth Morrow   24  ganderson@wheeler-atkins.info
# 4         8830     Kaitlyn Martinez   18           hayesdiane@gmail.com
# ..         ...                  ...  ...                            ...
# 195       3274  Catherine Velasquez   22              fsutton@gmail.com
# 196       3609         Joyce Thomas   19          zanderson@barrera.net
# 197       9179       Theresa Hughes   21             mstanley@yahoo.com
# 198       4463        Steven Golden   19             nvasquez@yahoo.com
# 199       6178     Miss April Smith   20       logansanchez@manning.com
#
#            Department   GPA  GraduationYear
# 0         Mathematics  3.16            2026
# ...
