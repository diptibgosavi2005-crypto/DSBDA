# %%
x = [10, 20, 30, 40]
x.insert(2, 25)
print(x)
# Out:
# [10, 20, 25, 30, 40]

# %%
p={}
print(type(p))
# Out:
# <class 'dict'>

# %%
x=set()
print(x)
# Out:
# set()

# %%
product={"pid":101,"pname":"Dipti"}
product["prize"]=200
print(product)
# Out:
# {'pid': 101, 'pname': 'Dipti', 'prize': 200}

# %%
a=(4,5,7,20)
b=list(a)
b.append(20)
a=tuple(b)
print(a)
# Out:
# (4, 5, 7, 20, 20)
