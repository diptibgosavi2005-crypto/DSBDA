# %% [markdown]
# name: Dipti Gosavi
# roll no:13205
# TE-B
# TITLE-Creation of Dataset using Microsoft Excel. 2. Identification and Handling of Outliers 3. Data Transformation for the purpose of : a. To change the scale for better understanding b. To decrease the skewness and convert distribution into normal distribution.

# %%
import pandas as pd

# %%
df=pd.read_csv("student.csv")

# %%
df
# Out:
#     math_score  reading_score  writing_score  placement_score  club join year  \
# 0         69.0           67.0           78.0             76.0            2021
# 1         62.0           73.0           76.0             86.0            2019
# 2         65.0           79.0           76.0            100.0            2020
# 3         78.0           66.0           74.0             97.0            2019
# 4         63.0            NaN           80.0             75.0            2019
# 5         66.0           94.0           62.0             98.0            2021
# 6         64.0           69.0           64.0             87.0            2019
# 7         70.0           63.0           69.0            100.0            2021
# 8         72.0           74.0           63.0              NaN            2020
# 9         80.0           76.0           68.0             83.0            2019
# 10       100.0           71.0           71.0             90.0            2020
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   math_score             34 non-null     float64
#  1   reading_score          31 non-null     float64
#  2   writing_score          33 non-null     float64
#  3   placement_score        34 non-null     float64
#  4   club join year         35 non-null     int64
#  5   placement offer count  35 non-null     int64
# dtypes: float64(4), int64(2)
# memory usage: 1.8 KB

# %%
df.isnull.sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df.isnull.sum()
#
# AttributeError: 'function' object has no attribute 'sum'

# %%
df.isnull()
# Out:
#     math_score  reading_score  writing_score  placement_score  club join year  \
# 0        False          False          False            False           False
# 1        False          False          False            False           False
# 2        False          False          False            False           False
# 3        False          False          False            False           False
# 4        False           True          False            False           False
# 5        False          False          False            False           False
# 6        False          False          False            False           False
# 7        False          False          False            False           False
# 8        False          False          False             True           False
# 9        False          False          False            False           False
# 10       False          False          False            False           False
# ...

# %%
import numpy as np

# %%
df.isnull.sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 df.isnull.sum()
#
# AttributeError: 'function' object has no attribute 'sum'

# %%
df.isnull().sum()
# Out:
# math_score               1
# reading_score            4
# writing_score            2
# placement_score          1
# club join year           0
# placement offer count    0
# dtype: int64

# %%
df.describe()
# Out:
#        math_score  reading_score  writing_score  placement_score  \
# count   34.000000      31.000000      33.000000        34.000000
# mean    72.441176      71.870968      68.636364        86.970588
# std      8.410640       7.083982       6.056083        12.427938
# min     61.000000      60.000000      60.000000        43.000000
# 25%     65.250000      66.000000      63.000000        83.500000
# 50%     72.500000      73.000000      69.000000        87.000000
# 75%     77.750000      76.000000      73.000000        96.750000
# max    100.000000      94.000000      80.000000       100.000000
#
#        club join year  placement offer count
# count       35.000000              35.000000
# mean      2019.685714               2.742857
# std          0.963188               0.443440
# min       2018.000000               2.000000
# 25%       2019.000000               2.500000
# 50%       2020.000000               3.000000
# 75%       2020.000000               3.000000
# ...

# %%
x=df.math_score.mean()

# %%
df.math_score.fillna(x,inplace=True)
# Out:
# C:\Users\gosav\AppData\Local\Temp\ipykernel_5404\3815807309.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.math_score.fillna(x,inplace=True)

# %%
df
# Out:
#     math_score  reading_score  writing_score  placement_score  club join year  \
# 0    69.000000           67.0           78.0             76.0            2021
# 1    62.000000           73.0           76.0             86.0            2019
# 2    65.000000           79.0           76.0            100.0            2020
# 3    78.000000           66.0           74.0             97.0            2019
# 4    63.000000            NaN           80.0             75.0            2019
# 5    66.000000           94.0           62.0             98.0            2021
# 6    64.000000           69.0           64.0             87.0            2019
# 7    70.000000           63.0           69.0            100.0            2021
# 8    72.000000           74.0           63.0              NaN            2020
# 9    80.000000           76.0           68.0             83.0            2019
# 10  100.000000           71.0           71.0             90.0            2020
# ...

# %%
y=df.reading_score.mean()

# %%
df.reading_score.fillna(y)
# Out:
# 0     67.000000
# 1     73.000000
# 2     79.000000
# 3     66.000000
# 4     71.870968
# 5     94.000000
# 6     69.000000
# 7     63.000000
# 8     74.000000
# 9     76.000000
# 10    71.000000
# 11    71.870968
# 12    76.000000
# 13    73.000000
# 14    78.000000
# 15    66.000000
# 16    60.000000
# 17    76.000000
# 18    78.000000
# 19    79.000000
# 20    65.000000
# 21    71.870968
# 22    75.000000
# 23    70.000000
# 24    76.000000
# 25    71.000000
# 26    61.000000
# 27    76.000000
# 28    64.000000
# 29    64.000000
# 30    77.000000
# 31    72.000000
# 32    71.870968
# 33    63.000000
# 34    76.000000
# Name: reading_score, dtype: float64

# %%
df.reading_score.fillna(y,inplace=True)
# Out:
# C:\Users\gosav\AppData\Local\Temp\ipykernel_5404\4092209863.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.reading_score.fillna(y,inplace=True)

# %%
df
# Out:
#     math_score  reading_score  writing_score  placement_score  club join year  \
# 0    69.000000      67.000000           78.0             76.0            2021
# 1    62.000000      73.000000           76.0             86.0            2019
# 2    65.000000      79.000000           76.0            100.0            2020
# 3    78.000000      66.000000           74.0             97.0            2019
# 4    63.000000      71.870968           80.0             75.0            2019
# 5    66.000000      94.000000           62.0             98.0            2021
# 6    64.000000      69.000000           64.0             87.0            2019
# 7    70.000000      63.000000           69.0            100.0            2021
# 8    72.000000      74.000000           63.0              NaN            2020
# 9    80.000000      76.000000           68.0             83.0            2019
# 10  100.000000      71.000000           71.0             90.0            2020
# ...

# %%
z = df.writing_score.mean()

# %%
df.writing_score.fillna(z,inplace=True)
# Out:
# C:\Users\gosav\AppData\Local\Temp\ipykernel_5404\1043828731.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.writing_score.fillna(z,inplace=True)

# %%
df
# Out:
#     math_score  reading_score  writing_score  placement_score  club join year  \
# 0    69.000000      67.000000      78.000000             76.0            2021
# 1    62.000000      73.000000      76.000000             86.0            2019
# 2    65.000000      79.000000      76.000000            100.0            2020
# 3    78.000000      66.000000      74.000000             97.0            2019
# 4    63.000000      71.870968      80.000000             75.0            2019
# 5    66.000000      94.000000      62.000000             98.0            2021
# 6    64.000000      69.000000      64.000000             87.0            2019
# 7    70.000000      63.000000      69.000000            100.0            2021
# 8    72.000000      74.000000      63.000000              NaN            2020
# 9    80.000000      76.000000      68.000000             83.0            2019
# 10  100.000000      71.000000      71.000000             90.0            2020
# ...

# %%
df.placement_score.fillna(222,inplace=True)
# Out:
# C:\Users\gosav\AppData\Local\Temp\ipykernel_5404\1146741468.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.placement_score.fillna(222,inplace=True)

# %%
df
# Out:
#     math_score  reading_score  writing_score  placement_score  club join year  \
# 0    69.000000      67.000000      78.000000             76.0            2021
# 1    62.000000      73.000000      76.000000             86.0            2019
# 2    65.000000      79.000000      76.000000            100.0            2020
# 3    78.000000      66.000000      74.000000             97.0            2019
# 4    63.000000      71.870968      80.000000             75.0            2019
# 5    66.000000      94.000000      62.000000             98.0            2021
# 6    64.000000      69.000000      64.000000             87.0            2019
# 7    70.000000      63.000000      69.000000            100.0            2021
# 8    72.000000      74.000000      63.000000            222.0            2020
# 9    80.000000      76.000000      68.000000             83.0            2019
# 10  100.000000      71.000000      71.000000             90.0            2020
# ...

# %%
df.placement offer count.fillna(10,inplace=True)
# Out:
#   Cell In[28], line 1
#     df.placement offer count.fillna(10,inplace=True)
#                  ^
# SyntaxError: invalid syntax

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df.columns
# Out:
# Index(['math_score', 'reading_score', 'writing_score', 'placement_score',
#        'club join year', 'placement offer count'],
#       dtype='object')

# %%
col = ['math_score', 'reading_score', 'writing_score', 'placement_score',
       'club join year', 'placement offer count']

# %%
df.boxplot(col)
# Out:
# <Axes: >

# %%
col1 = ['math_score', 'reading_score', 'writing_score', 'placement_score']

# %%
df.boxplot(col1)
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt

# %%
plt.show()

# %%
plt.scatterplot(placement_score, placement offer count)
# Out:
#   Cell In[37], line 1
#     plt.scatterplot(placement_score, placement offer count)
#                                      ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
df.rename(columns={'placement offer count': 'Placement_Offer_Count'}, inplace=True)

# %%
df
# Out:
#     math_score  reading_score  writing_score  placement_score  club join year  \
# 0    69.000000      67.000000      78.000000             76.0            2021
# 1    62.000000      73.000000      76.000000             86.0            2019
# 2    65.000000      79.000000      76.000000            100.0            2020
# 3    78.000000      66.000000      74.000000             97.0            2019
# 4    63.000000      71.870968      80.000000             75.0            2019
# 5    66.000000      94.000000      62.000000             98.0            2021
# 6    64.000000      69.000000      64.000000             87.0            2019
# 7    70.000000      63.000000      69.000000            100.0            2021
# 8    72.000000      74.000000      63.000000            222.0            2020
# 9    80.000000      76.000000      68.000000             83.0            2019
# 10  100.000000      71.000000      71.000000             90.0            2020
# ...

# %%
df.rename(columns={'club join year': 'Club_Join_Date'}, inplace=True)

# %%
plt.scatterplot(placement_score, Placement_Offer_Count)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 plt.scatterplot(placement_score, Placement_Offer_Count)
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'scatterplot'

# %%
fig, ax = plt.subplots(figsize = (18,10))

# %%
ax.scatter(df['placement_score'], df['Placement_Offer_Count'])

# %%
plt.show()

# %%
q1 = np.percentile(df.Placement_Offer_Count , 25)

# %%
q1
# Out:
# 2.5

# %%
df.describe()
# Out:
#        math_score  reading_score  writing_score  placement_score  \
# count   35.000000      35.000000      35.000000        35.000000
# mean    72.441176      71.870968      68.636364        90.828571
# std      8.286031       6.654242       5.875263        25.900813
# min     61.000000      60.000000      60.000000        43.000000
# 25%     65.500000      66.500000      63.000000        84.000000
# 50%     72.441176      71.870968      69.000000        87.000000
# 75%     77.500000      76.000000      72.500000        97.500000
# max    100.000000      94.000000      80.000000       222.000000
#
#        Club_Join_Date  Placement_Offer_Count
# count       35.000000              35.000000
# mean      2019.685714               2.742857
# std          0.963188               0.443440
# min       2018.000000               2.000000
# 25%       2019.000000               2.500000
# 50%       2020.000000               3.000000
# 75%       2020.000000               3.000000
# ...
